# %%
 import pandas as pd

# %%
train = pd.read_csv("train.csv")
test= pd.read_csv("test.csv")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
genders = {"male": 0, "female": 1}
data=[train,test]

for item in data:
    item["Sex"] = item["Sex"].map(genders)

# %%
data=[train,test]

for item in data:
    item["Age"].fillna(item["Age"].mean(),inplace=True)
    item["Age"]=round(item["Age"]).astype(int)
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1
# 2                               Heikkinen, Miss. Laina    1   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1
# 4                             Allen, Mr. William Henry    0   35      0
# ..                                                 ...  ...  ...    ...
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,4))
plt.scatter( train["Age"],train["Survived"])
    
plt.xlabel("Age")
plt.ylabel("Survived")
plt.show()

# %%
data=[train,test]

for item in data:
    item.loc[item.Age <= 11, "Age"] = 0
    item.loc[(item["Age"]>11) & (item["Age"]<=25), "Age"]=1
    item.loc[(train["Age"]>25) & (item["Age"]<=40), "Age"]=2
    item.loc[(train["Age"]>40) & (item["Age"]<=60), "Age"]=3
    item.loc[(train["Age"]>60), "Age"]=4

train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0    1      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1    2      1
# 2                               Heikkinen, Miss. Laina    1    2      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1    2      1
# 4                             Allen, Mr. William Henry    0    2      0
# ..                                                 ...  ...  ...    ...
# ...

# %%
train = train.drop(['Name','Ticket','Fare','Cabin'], axis=1)
test = test.drop(['Name','Ticket','Fare','Cabin'], axis=1)
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch Embarked
# 0            1         0       3    0    1      1      0        S
# 1            2         1       1    1    2      1      0        C
# 2            3         1       3    1    2      0      0        S
# 3            4         1       1    1    2      1      0        S
# 4            5         0       3    0    2      0      0        S

# %% [markdown]
# #Referenced Contribution

# %%
data=[train,test]

for item in data:
    family_size = []
    is_alone = []
    
    for i in range(len(item)):
        family_size.append(item['Parch'][i]+item['SibSp'][i])
        if family_size[-1] == 0:
            is_alone.append(1)
        else:
            is_alone.append(0)
        
    item['Family_size'] = family_size
    item['Is_alone'] = is_alone

train
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch Embarked  \
# 0              1         0       3    0    1      1      0        S
# 1              2         1       1    1    2      1      0        C
# 2              3         1       3    1    2      0      0        S
# 3              4         1       1    1    2      1      0        S
# 4              5         0       3    0    2      0      0        S
# ..           ...       ...     ...  ...  ...    ...    ...      ...
# 886          887         0       2    0    2      0      0        S
# 887          888         1       1    1    1      0      0        S
# 888          889         0       3    1    2      1      2        S
# 889          890         1       1    0    2      0      0        C
# 890          891         0       3    0    2      0      0        Q
#
#      Family_size  Is_alone
# 0              1         0
# 1              1         0
# 2              0         1
# 3              1         0
# ...

# %% [markdown]
# # Assigning common part - refrenced part

# %%
common= 'S'
data = [train, test]

for item in data:
    item['Embarked'] = item['Embarked'].fillna(common)
    
class_embark = {"S": 0, "C": 1, "Q": 2}

for item in data:
    item['Embarked'] = item['Embarked'].map(class_embark)
    
train
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch  Embarked  \
# 0              1         0       3    0    1      1      0         0
# 1              2         1       1    1    2      1      0         1
# 2              3         1       3    1    2      0      0         0
# 3              4         1       1    1    2      1      0         0
# 4              5         0       3    0    2      0      0         0
# ..           ...       ...     ...  ...  ...    ...    ...       ...
# 886          887         0       2    0    2      0      0         0
# 887          888         1       1    1    1      0      0         0
# 888          889         0       3    1    2      1      2         0
# 889          890         1       1    0    2      0      0         1
# 890          891         0       3    0    2      0      0         2
#
#      Family_size  Is_alone
# 0              1         0
# 1              1         0
# 2              0         1
# ...

# %%
X_train = train.drop("Survived", axis=1)
Y_train = train["Survived"]

# %% [markdown]
# # cross - val score - referenced part

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics


model = RandomForestClassifier(random_state = 1 , max_depth = 7 , max_features='auto' , n_estimators = 900)
model.fit(X_train , Y_train)

model_accuracies = cross_val_score(estimator = rfc , X = X_train , y = Y_train , cv = 10 , scoring = 'accuracy')
model_acc = rfc_accuracies.mean()

print("accuracy = " , model_acc)
# Out:
# accuracy =  0.8125717852684146

# %%
Y_prediction = model.predict(test)

# %%
output = pd.DataFrame({'PassengerId': test.PassengerId, 'Survived': Y_prediction})
output.to_csv('my_submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!
